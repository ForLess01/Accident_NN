# %% [markdown]
# # 01 - Análisis exploratorio de datos\n\nEjecución reproducible del Bloque C. Las figuras, tablas e interpretaciones se generan desde `src/block_c_eda.py`.

# %%
from src.block_c_eda import run_block_c\n\nsummary = run_block_c()\nsummary

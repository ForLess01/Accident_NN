# %% [markdown]
# # 04 - Evaluación final e interpretabilidad\n\nEjecución reproducible del Bloque F. Este bloque toca el test final una sola vez mediante `src/block_f_evaluation.py`.

# %%
from src.block_f_evaluation import run_block_f\n\nsummary = run_block_f()\nsummary

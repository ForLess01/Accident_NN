# %% [markdown]
# # Evaluación y artefactos definitivos
#
# Completa calibración con 2023 y regenera la referencia histórica 2024-2025 sin modificar arquitectura, pesos ni selección.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.final_model_bundle import build_canonical_bundle
from src.final_evaluation_figures import generate_final_figures

manifest = build_canonical_bundle()
figures = generate_final_figures()
{"model_version": manifest["model_version"], "reference": manifest["reference_evaluation"]["metrics"], "figures": figures}

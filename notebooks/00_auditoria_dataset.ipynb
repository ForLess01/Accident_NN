# %% [markdown]
# # 00 - Auditoría del dataset\n\nAuditoría inicial del Bloque B. La lógica ejecutable vive en `src/block_b_dataset_audit.py` para mantener reproducibilidad fuera del notebook.

# %%
from src.block_b_dataset_audit import audit_and_clean\n\nsummary = audit_and_clean()\nsummary
